# %% [markdown]
# # Importing libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectFromModel

# %%
x=pd.read_csv('train.csv')
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
# Viewing datasets
train.head()
# Out:
#    Id  Age  Attrition BusinessTravel              Department  \
# 0   1   30          0     Non-Travel  Research & Development
# 1   2   36          0  Travel_Rarely  Research & Development
# 2   3   55          1  Travel_Rarely                   Sales
# 3   4   39          0  Travel_Rarely  Research & Development
# 4   5   37          0  Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 2          3        Medical             571
# 1                12          4  Life Sciences            1614
# 2                 2          1        Medical             842
# 3                24          1  Life Sciences            2014
# 4                 3          3          Other             689
#
#    EnvironmentSatisfaction  ... PerformanceRating  StockOptionLevel  \
# 0                        3  ...                 3                 0
# 1                        3  ...                 3                 2
# 2                        3  ...                 3                 0
# 3                        1  ...                 3                 0
# 4                        3  ...                 3                 1
#
#   TotalWorkingYears  TrainingTimesLastYear YearsAtCompany  YearsInCurrentRole  \
# 0                12                      2             11                   7
# 1                 7                      2              3                   2
# 2                12                      3              9                   7
# 3                18                      2              7                   7
# 4                10                      2             10                   7
#
#    YearsSinceLastPromotion YearsWithCurrManager  CommunicationSkill  Behaviour
# 0                        6                    7                   4          1
# 1                        1                    1                   2          1
# 2                        7                    3                   5          1
# 3                        1                    7                   4          1
# 4                        7                    8                   1          1
#
# [5 rows x 29 columns]

# %%
print(train.shape)
# Out:
# (1628, 29)

# %%
test.head()
# Out:
#    Id  Age BusinessTravel              Department  DistanceFromHome  \
# 0   1   28  Travel_Rarely  Research & Development                 9
# 1   2   31  Travel_Rarely                   Sales                 6
# 2   3   37  Travel_Rarely  Research & Development                 6
# 3   4   42  Travel_Rarely  Research & Development                 1
# 4   5   45     Non-Travel  Research & Development                 4
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          3        Medical             377                        4    Male
# 1          4        Medical             653                        1    Male
# 2          3        Medical             474                        3    Male
# 3          2  Life Sciences             827                        4  Female
# 4          2  Life Sciences             972                        3    Male
#
#    ...  PerformanceRating StockOptionLevel  TotalWorkingYears  \
# 0  ...                  4                1                  5
# 1  ...                  4                2                 13
# 2  ...                  3                2                 13
# 3  ...                  3                1                  8
# 4  ...                  3                0                  9
#
#   TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# 0                     3               5                   2
# 1                     4               7                   7
# 2                     2               7                   7
# 3                     4               4                   3
# 4                     5               9                   7
#
#   YearsSinceLastPromotion  YearsWithCurrManager  CommunicationSkill  Behaviour
# 0                       0                     4                   5          1
# 1                       5                     7                   3          1
# 2                       6                     7                   4          1
# 3                       0                     2                   5          1
# 4                       0                     8                   2          1
#
# [5 rows x 28 columns]

# %%
print(test.shape)
# Out:
# (470, 28)

# %%
print(train.isna().sum())
# Out:
# Id                         0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeNumber             0
# EnvironmentSatisfaction    0
# Gender                     0
# JobInvolvement             0
# JobRole                    0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# PerformanceRating          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# CommunicationSkill         0
# Behaviour                  0
# dtype: int64

# %%
print(test.isna().sum())
# Out:
# Id                         0
# Age                        0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeNumber             0
# EnvironmentSatisfaction    0
# Gender                     0
# JobInvolvement             0
# JobRole                    0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# PerformanceRating          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# CommunicationSkill         0
# Behaviour                  0
# dtype: int64

# %%
ytrain=train["Attrition"]
train1=train.drop(["Attrition"],axis=1)
train1.head()
# Out:
#    Id  Age BusinessTravel              Department  DistanceFromHome  \
# 0   1   30     Non-Travel  Research & Development                 2
# 1   2   36  Travel_Rarely  Research & Development                12
# 2   3   55  Travel_Rarely                   Sales                 2
# 3   4   39  Travel_Rarely  Research & Development                24
# 4   5   37  Travel_Rarely  Research & Development                 3
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          3        Medical             571                        3  Female
# 1          4  Life Sciences            1614                        3  Female
# 2          1        Medical             842                        3    Male
# 3          1  Life Sciences            2014                        1    Male
# 4          3          Other             689                        3    Male
#
#    ...  PerformanceRating StockOptionLevel  TotalWorkingYears  \
# 0  ...                  3                0                 12
# 1  ...                  3                2                  7
# 2  ...                  3                0                 12
# 3  ...                  3                0                 18
# 4  ...                  3                1                 10
#
#   TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# 0                     2              11                   7
# 1                     2               3                   2
# 2                     3               9                   7
# 3                     2               7                   7
# 4                     2              10                   7
#
#   YearsSinceLastPromotion  YearsWithCurrManager  CommunicationSkill  Behaviour
# 0                       6                     7                   4          1
# 1                       1                     1                   2          1
# 2                       7                     3                   5          1
# 3                       1                     7                   4          1
# 4                       7                     8                   1          1
#
# [5 rows x 28 columns]

# %%
list(train.select_dtypes(['object']).columns)
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
list(test.select_dtypes(['object']).columns)
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %% [markdown]
# # Exploratory Data Analysis

# %%
train.Attrition.value_counts(normalize=False)
# Out:
# Attrition
# 0    843
# 1    785
# Name: count, dtype: int64

# %% [markdown]
# According to the train data 52% employees did not leave the company, while 48% employees left the company.

# %%
print(train[train.Attrition==0]["MonthlyIncome"].mean())
print(train[train.Attrition==1]["MonthlyIncome"].mean())
# Out:
# 6792.187425860024
# 4704.484076433121

# %% [markdown]
# Here the mean salary of employess who left company is 4704 and for employees who did not leave the company is 6792.

# %%
#for analyzing the job role in each department

# %%
for dept in train['Department'].unique():
    print('\n', dept, ':')
    print(train[train['Department']==dept]['JobRole'].value_counts())
# Out:
#  Research & Development :
# JobRole
# Research Scientist           341
# Laboratory Technician        310
# Manufacturing Director       121
# Healthcare Representative    110
# Manager                       50
# Research Director             47
# Name: count, dtype: int64
#
#  Sales :
# JobRole
# Sales Executive         365
# Sales Representative    172
# Manager                  31
# Name: count, dtype: int64
#
#  Human Resources :
# JobRole
# Human Resources    72
# Manager             9
# Name: count, dtype: int64

# %%
#Data Visualiization

# %%
sns.axes_style('whitegrid')
sns.catplot(x="Department", data=train, aspect=1, kind='count', hue='Attrition', palette=['C1', 'C0']).set_ylabels('Number of Employees')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[144], line 2
#       1 sns.axes_style('whitegrid')
# ----> 2 sns.catplot(x="Department", data=train, aspect=1, kind='count', hue='Attrition', palette=['C1', 'C0']).set_ylabels('Number of Employees')
#
# File ~\anaconda3\envs\venv\lib\site-packages\seaborn\categorical.py:3187, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3185 p = _CategoricalPlotter()
#    3186 p.require_numeric = plotter_class.require_numeric
# -> 3187 p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3188 if (
#    3189     order is not None
#    3190     or (sharex and p.orient == "v")
#    3191     or (sharey and p.orient == "h")
#    3192 ):
#    3193     # Sync categorical axis between facets to have the same categories
#    3194     order = p.group_names
#
# File ~\anaconda3\envs\venv\lib\site-packages\seaborn\categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'Department'

# %%
sns.histplot(train['MonthlyIncome']);

# %%
sns.axes_style('whitegrid')
sns.catplot(x="OverTime", data=train, aspect=1, kind='count', hue='Attrition', 
            palette=['C1', 'C0']).set_ylabels('Number of Employees')
# Out:
# C:\Users\ADMIN\anaconda3\envs\venv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(8,6))
sns.axes_style('whitegrid')
sns.catplot(x="JobRole", data=train, aspect=4, kind='count', hue='Attrition',
            palette=['C1', 'C0']).set_ylabels('Number of Employees')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[147], line 3
#       1 plt.figure(figsize=(8,6))
#       2 sns.axes_style('whitegrid')
# ----> 3 sns.catplot(x="JobRole", data=train, aspect=4, kind='count', hue='Attrition',
#       4             palette=['C1', 'C0']).set_ylabels('Number of Employees')
#
# File ~\anaconda3\envs\venv\lib\site-packages\seaborn\categorical.py:3187, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3185 p = _CategoricalPlotter()
#    3186 p.require_numeric = plotter_class.require_numeric
# -> 3187 p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3188 if (
#    3189     order is not None
#    3190     or (sharex and p.orient == "v")
#    3191     or (sharey and p.orient == "h")
#    3192 ):
#    3193     # Sync categorical axis between facets to have the same categories
#    3194     order = p.group_names
#
# File ~\anaconda3\envs\venv\lib\site-packages\seaborn\categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'JobRole'

# %%
plt.figure(figsize=(8,6))
sns.axes_style('whitegrid')
sns.catplot(x="Gender", data=train, aspect=4, kind='count', hue='Attrition',
            palette=['C1', 'C0']).set_ylabels('Number of Employees');
# Out:
# C:\Users\ADMIN\anaconda3\envs\venv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(8,6))
sns.axes_style('whitegrid')
sns.catplot(x="MaritalStatus", data=train, aspect=1, kind='count', hue='Attrition',
            palette=['C1', 'C0']).set_ylabels('Number of Employees')
# Out:
# C:\Users\ADMIN\anaconda3\envs\venv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.axes_style('whitegrid')
sns.catplot(x="BusinessTravel", data=train, aspect=1, kind='count', hue='Attrition', 
            palette=['C1', 'C0']).set_ylabels('Number of Employees')
# Out:
# C:\Users\ADMIN\anaconda3\envs\venv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
ytrain.value_counts().plot(kind='bar', color=('C0','C1')).set_title('Attrition')
# Out:
# Text(0.5, 1.0, 'Attrition')

# %%
numeric_columns = train.select_dtypes(include='number')
corr = numeric_columns.corr().abs()

plt.figure(figsize=(15, 15))
sns.heatmap(corr, annot=True, cmap="RdYlGn", annot_kws={"size": 10})
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,6))
plt.grid(True,alpha=0.5)
sns.kdeplot(train.loc[train['Attrition'] == 0, 'Age'], label = 'Active Employee')
sns.kdeplot(train.loc[train['Attrition'] == 1, 'Age'], label = 'Ex-Employees')
plt.xlim(left=train.Age.min(), right=train.Age.max())
plt.xlabel('Age (years)')
plt.ylabel('Density')
plt.title('Age Distribution in Percent by Attrition Status');

# %%
plt.figure(figsize=(15,6))
plt.grid(True, alpha=0.5)
sns.kdeplot(train.loc[train['Attrition'] == 0, 'DistanceFromHome'], label = 'Active Employee')
sns.kdeplot(train.loc[train['Attrition'] == 1, 'DistanceFromHome'], label = 'Ex-Employees')
plt.xlim(left=train['DistanceFromHome'].min(), right=train['DistanceFromHome'].max())
plt.xlabel('distance')
plt.ylabel('Density')
plt.title('distance from home distribution by Attrition Status');

# %% [markdown]
# # Splitting the full train data into train and validation set.

# %%
def column_index(train, query_cols):
    cols = train.columns.values
    sidx = np.argsort(cols)
    return sidx[np.searchsorted(cols,query_cols,sorter=sidx)]
column_index(train, ['Age', 'DistanceFromHome','MonthlyIncome','NumCompaniesWorked',
 'PercentSalaryHike',
 'PerformanceRating',
 'StockOptionLevel',
 'TotalWorkingYears',
 'TrainingTimesLastYear',
 'YearsAtCompany',
 'YearsInCurrentRole',
 'YearsSinceLastPromotion',
 'YearsWithCurrManager'])
# Out:
# array([ 1,  5, 15, 16, 18, 19, 20, 21, 22, 23, 24, 25, 26], dtype=int64)

# %% [markdown]
# finding the index of the numerical columns in train data set so, I defined this function.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler() 
scaled_values = scaler.fit_transform(train.iloc[:,[ 1,  5, 15, 16, 18, 19, 20, 21, 22, 23, 24, 25, 26]]) 
train.iloc[:,[ 1,  5, 15, 16, 18, 19, 20, 21, 22, 23, 24, 25, 26]] = scaled_values

# %%
train.head()
# Out:
#    Id       Age  Attrition BusinessTravel              Department  \
# 0   1  0.285714          0     Non-Travel  Research & Development
# 1   2  0.428571          0  Travel_Rarely  Research & Development
# 2   3  0.880952          1  Travel_Rarely                   Sales
# 3   4  0.500000          0  Travel_Rarely  Research & Development
# 4   5  0.452381          0  Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0          0.035714          3        Medical             571
# 1          0.392857          4  Life Sciences            1614
# 2          0.035714          1        Medical             842
# 3          0.821429          1  Life Sciences            2014
# 4          0.071429          3          Other             689
#
#    EnvironmentSatisfaction  ... PerformanceRating  StockOptionLevel  \
# 0                        3  ...                 0          0.000000
# 1                        3  ...                 0          0.666667
# 2                        3  ...                 0          0.000000
# 3                        1  ...                 0          0.000000
# 4                        3  ...                 0          0.333333
#
#   TotalWorkingYears  TrainingTimesLastYear YearsAtCompany  YearsInCurrentRole  \
# 0          0.315789               0.333333       0.297297            0.388889
# 1          0.184211               0.333333       0.081081            0.111111
# 2          0.315789               0.500000       0.243243            0.388889
# 3          0.473684               0.333333       0.189189            0.388889
# 4          0.263158               0.333333       0.270270            0.388889
#
#    YearsSinceLastPromotion YearsWithCurrManager  CommunicationSkill  Behaviour
# 0                 0.400000             0.411765                   4          1
# 1                 0.066667             0.058824                   2          1
# 2                 0.466667             0.176471                   5          1
# 3                 0.066667             0.411765                   4          1
# 4                 0.466667             0.470588                   1          1
#
# [5 rows x 29 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
le_count = 0
for col in train.columns.values:
    if train[col].dtype == 'object':
        if len(list(train[col].unique())) <= 2:
            le.fit(train[col])
            train[col] = le.transform(train[col])
            le_count += 1
print('{} columns were label encoded.'.format(le_count))
# Out:
# 2 columns were label encoded.

# %%
train = pd.get_dummies(train, drop_first=True)  
print(train.shape)
train.head()
# Out:
# (1628, 43)
#    Id       Age  Attrition  DistanceFromHome  Education  EmployeeNumber  \
# 0   1  0.285714          0          0.035714          3             571
# 1   2  0.428571          0          0.392857          4            1614
# 2   3  0.880952          1          0.035714          1             842
# 3   4  0.500000          0          0.821429          1            2014
# 4   5  0.452381          0          0.071429          3             689
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobSatisfaction  ...  \
# 0                        3       0               3                4  ...
# 1                        3       0               3                3  ...
# 2                        3       1               3                4  ...
# 3                        1       1               3                4  ...
# 4                        3       1               3                3  ...
#
#    JobRole_Human Resources  JobRole_Laboratory Technician  JobRole_Manager  \
# 0                    False                           True            False
# 1                    False                          False            False
# 2                    False                          False            False
# 3                    False                          False            False
# 4                    False                          False            False
#
#    JobRole_Manufacturing Director  JobRole_Research Director  \
# 0                           False                      False
# 1                            True                      False
# 2                           False                      False
# 3                           False                      False
# 4                            True                      False
#
#    JobRole_Research Scientist  JobRole_Sales Executive  \
# 0                       False                    False
# 1                       False                    False
# 2                       False                     True
# 3                        True                    False
# 4                       False                    False
#
#    JobRole_Sales Representative  MaritalStatus_Married  MaritalStatus_Single
# 0                         False                  False                  True
# 1                         False                   True                 False
# 2                         False                  False                  True
# 3                         False                  False                  True
# 4                         False                   True                 False
#
# [5 rows x 43 columns]

# %%
column_index(test, ['Age', 'DistanceFromHome','MonthlyIncome','NumCompaniesWorked',
 'PercentSalaryHike',
 'PerformanceRating',
 'StockOptionLevel',
 'TotalWorkingYears',
 'TrainingTimesLastYear',
 'YearsAtCompany',
 'YearsInCurrentRole',
 'YearsSinceLastPromotion',
 'YearsWithCurrManager'])
# Out:
# array([ 1,  4, 14, 15, 17, 18, 19, 20, 21, 22, 23, 24, 25], dtype=int64)

# %%
scaled_values1 = scaler.fit_transform(test.iloc[:,[ 1,  4, 14, 15, 17, 18, 19, 20, 21, 22, 23, 24, 25]]) 
test.iloc[:,[ 1,  4, 14, 15, 17, 18, 19, 20, 21, 22, 23, 24, 25]] = scaled_values1

# %%
le_count = 0
for col in test.columns.values:
    if test[col].dtype == 'object':
        if len(list(test[col].unique())) <= 2:
            le.fit(test[col])
            test[col] = le.transform(test[col])
            le_count += 1
print('{} columns were label encoded.'.format(le_count))
# Out:
# 2 columns were label encoded.

# %%
test = pd.get_dummies(test, drop_first=True)  
print(test.shape)
test.head()
# Out:
# (470, 42)
#    Id       Age  DistanceFromHome  Education  EmployeeNumber  \
# 0   1  0.238095          0.285714          3             377
# 1   2  0.309524          0.178571          4             653
# 2   3  0.452381          0.178571          3             474
# 3   4  0.571429          0.000000          2             827
# 4   5  0.642857          0.107143          2             972
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobSatisfaction  \
# 0                        4       1               3                4
# 1                        1       1               4                4
# 2                        3       1               4                1
# 3                        4       0               2                4
# 4                        3       1               3                2
#
#    MonthlyIncome  ...  JobRole_Human Resources  JobRole_Laboratory Technician  \
# 0       0.051931  ...                    False                          False
# 1       0.231753  ...                    False                          False
# 2       0.259018  ...                    False                          False
# 3       0.263686  ...                    False                          False
# 4       0.178018  ...                    False                           True
#
#    JobRole_Manager  JobRole_Manufacturing Director  JobRole_Research Director  \
# 0            False                           False                      False
# 1            False                           False                      False
# 2            False                           False                      False
# 3            False                            True                      False
# 4            False                           False                      False
#
#    JobRole_Research Scientist  JobRole_Sales Executive  \
# 0                        True                    False
# 1                       False                     True
# 2                        True                    False
# 3                       False                    False
# 4                       False                    False
#
#    JobRole_Sales Representative  MaritalStatus_Married  MaritalStatus_Single
# 0                         False                   True                 False
# 1                         False                  False                 False
# 2                         False                  False                 False
# 3                         False                   True                 False
# 4                         False                   True                 False
#
# [5 rows x 42 columns]

# %%
X = train.drop('Attrition',axis=1)
X['MonthlyIncome'] = np.cbrt(X['MonthlyIncome'])
X['TotalWorkingYears'] = np.cbrt(X['TotalWorkingYears'])
X['YearsAtCompany'] = np.cbrt(X['YearsAtCompany'])
X['YearsSinceLastPromotion'] = np.cbrt(X['YearsSinceLastPromotion'])
X['DistanceFromHome'] = np.cbrt(X['DistanceFromHome'])
Y = train['Attrition']
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.3,random_state=1)

# %% [markdown]
# # Classification Techniques

# %%
rf = RandomForestClassifier(n_estimators=100, random_state = 0,max_features = 14)
rf.fit(X_train,Y_train)
print('For Random Forest Classifier')
score = roc_auc_score(Y_train, rf.predict_proba(X_train)[:,1])
print('Train roc_auc_score:',score)
score = roc_auc_score(Y_test, rf.predict_proba(X_test)[:,1])
print("Test roc_auc_score:",score)
# Out:
# For Random Forest Classifier
# Train roc_auc_score: 1.0
# Test roc_auc_score: 0.9810799959851451

# %%
gbc = GradientBoostingClassifier(n_estimators=100, random_state = 0,learning_rate = 1,max_features=5)
gbc.fit(X_train,Y_train)
print('For Gradient Boost Classifier')
score = roc_auc_score(Y_train, gbc.predict_proba(X_train)[:,1])
print('Train roc_auc_score:',score)
score = roc_auc_score(Y_test, gbc.predict_proba(X_test)[:,1])
print("Test roc_auc_score:",score)
# Out:
# For Gradient Boost Classifier
# Train roc_auc_score: 1.0
# Test roc_auc_score: 0.9760781558432868

# %%
dtc = DecisionTreeClassifier(random_state = 0,max_features=24)
dtc.fit(X_train,Y_train)
print('For Decision Tree Classifier')
score = roc_auc_score(Y_train, dtc.predict_proba(X_train)[:,1])
print('Train roc_auc_score:',score)
score = roc_auc_score(Y_test, dtc.predict_proba(X_test)[:,1])
print("Test roc_auc_score:",score)
# Out:
# For Decision Tree Classifier
# Train roc_auc_score: 1.0
# Test roc_auc_score: 0.8510237880156579

# %%
svc = SVC(probability=True,kernel='rbf',C=0.1,gamma=0.001)
svc.fit(X_train,Y_train)
print('For Support Vector Classifier')
score = roc_auc_score(Y_train, svc.predict_proba(X_train)[:,1])
print('Train roc_auc_score:',score)
score = roc_auc_score(Y_test, svc.predict_proba(X_test)[:,1])
print("Test roc_auc_score:",score)
# Out:
# For Support Vector Classifier
# Train roc_auc_score: 0.9971382125881562
# Test roc_auc_score: 0.8951704640503195

# %%
log_reg = LogisticRegression(C = 1.8,max_iter=300,solver='liblinear',random_state=7) 
log_reg.fit(X_train,Y_train)
print('For Logistic Regression')
score = roc_auc_score(Y_train, log_reg.predict_proba(X_train)[:,1])
print('Train roc_auc_score:',score)
score = roc_auc_score(Y_test, log_reg.predict_proba(X_test)[:,1])
print("Test roc_auc_score:",score)
# Out:
# For Logistic Regression
# Train roc_auc_score: 0.9464697410793204
# Test roc_auc_score: 0.9601191073639131

# %%
from xgboost import XGBClassifier

xb =XGBClassifier(max_depth=3, n_estimators=300, learning_rate=0.4)
xb.fit(X_train,Y_train)
print('For xb Classifier')
score = roc_auc_score(Y_train, xb.predict_proba(X_train)[:,1])
print('Train roc_auc_score:',score)
score = roc_auc_score(Y_test, xb.predict_proba(X_test)[:,1])
print("Test roc_auc_score:",score)
# Out:
# For xb Classifier
# Train roc_auc_score: 1.0
# Test roc_auc_score: 0.979273311251631

# %%
models = [rf,gbc,dtc,svc,log_reg,xb]
for model in models:
    model.fit(X,Y)

# %% [raw]
# Performing similar operations on test data like we did on train data

# %%
new_test = test.copy()
for col in new_test.columns:
    if(isinstance(test[col][0],str)):
        new_test[col] = LabelEncoder().fit_transform(new_test[col])
new_test = new_test.drop(['Id','EmployeeNumber'],axis = 1)
X_test = new_test
X_test['MonthlyIncome'] = np.cbrt(X_test['MonthlyIncome'])
X_test['TotalWorkingYears'] = np.cbrt(X_test['TotalWorkingYears'])
X_test['YearsAtCompany'] = np.cbrt(X_test['YearsAtCompany'])
X_test['YearsSinceLastPromotion'] = np.cbrt(X_test['YearsSinceLastPromotion'])
X_test['DistanceFromHome'] = np.cbrt(X_test['DistanceFromHome'])

# %% [markdown]
# # Output Results

# %%
models = [rf,gbc,dtc,svc,log_reg,xb]
modelname = ['Random Forest','GradientBoost','DecisionTree','SupportVector','log_reg','xbclass10']
for model,name in zip(models,modelname):
    test_prob = model.predict_proba(test)[:,1]
    result = pd.DataFrame({'Id':list(test['Id']),'Attrition':list(test_prob)})
    result.to_csv('prediction_log.csv',index=False)

# %% [raw]
# Here it will create .csv file which contains Id and Attrition of the employees.

# %%
result
# Out:
#       Id  Attrition
# 0      1   0.000346
# 1      2   0.003885
# 2      3   0.004715
# 3      4   0.057694
# 4      5   0.006031
# ..   ...        ...
# 465  466   0.017652
# 466  467   0.997166
# 467  468   0.131377
# 468  469   0.000805
# 469  470   0.002441
#
# [470 rows x 2 columns]
